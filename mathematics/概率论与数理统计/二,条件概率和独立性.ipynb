# %% [markdown]
# # 二, 条件概率和独立性
#
#
# ## 1, 条件概率
#
# 例1： 考虑恰好有两个小孩的家庭,并且假定生男, 生女是等可能的。如果从这些家庭中随机地选择一个孩子，并发现她为女孩，问在她家里另一个孩子是男孩的概率是多少？
#
# 解:
#    样本空间: {男g,男b,女g,女b}，
#
#    设事件A为 "这个孩子是女孩"， 事件B为"这个孩子有一个兄弟"
#
#    A={女g，女b}， B={男b， 女b}
#
#    AB = {女b}
#
#    所求概率为 p（B|A） = $\frac{P(AB)}{P(A)}$= $\frac{ \frac{1}{4}}{\frac{2}{4}}$ = $\frac{1}{2}$
#
#
#
# 选择题：
#
# 1. 根据本题题干回答以下（1）（2）题
#
#    某班级学生的考试成绩数学不及格的占15%，语文不及格的占5%，这两门课都不及格的占3%
#
#
#
#     （1）已知一学生数学不及格，他语文也不及格的概率是多少？
#
#        A. 0.2    B. 0.375   C. 0.5  D. 0.6
#
#      2）已知一学生语文不及格，他数学也不及格的概率是多少？
#
#        A. 0.2    B. 0.375   C. 0.5  D. 0.6
#
#
#
# 2. 设一批产品中一、二、三等品各占60%, 35%, 5%．从中任意取出一件，结果不是三等品，求取到的是一等品的概率．
#
#     A. 3/5    B. 12/19    C. 5/19   D.10/19
#
#
#
# 3. 以某种动物由出生活到10岁的概率为0.8，而活到15岁的概率为0.5，问现年为10岁的这种动物能活到15岁的概率是多少？
#
#     A. 1/2    B. 3/8     C. 5/8     D. 7/8
#
#
# 4. 设10件产品中有4件不合格品，从中任取两件，已知其中一件是不合格品，求另一件也是不合格品的概率为
#
#     A. 0.1   B. 0.15    C. 0.2   D. 0.25
#
#
# ## 2, 有关条件概率的三个重要计算公式
#
# ### ① 乘法公式
#
# 1. 设A,B是两个事件,P(B) > 0, 则P(AB) = P(B)P(A | B)
#
#     证明: P(A | B) = $\frac{P(AB)}{P(B)}$  $\Rightarrow$ P(AB) = P(B)P(A|B)
#
# 2. 设$A_1,A_2,A_3,...A_n$为n个事件,且$P(A_1, A_2,...A_{n-1})>0$，则
#
# $P（A_1, A_2, ... A_n）= P(A_1) * P(A_2 | A_1) * P(A_3 | A_1 A_2)...P(A_n | A_1 A_2 ... A_{n-1})$
#
#    证明: 数学归纳法,设 $P(A_1...A_k) = P(A_1) * P(A_2 | A_1) * P(A_k | A_1...A_{k-1})$,
#
#    $P(A_1 ... A_{k+1}) = P(A_1 A_2 ... A_k)* P(A_{k+1} | A_1 A_2 ... A_k)$
#
#    = $P(A_1)*P(A_2|A_1)...P(A_{k+1} | A_1 A_2 ... A_k)$
#
#
# 直接验证
#
# $P(A_1)*P(A_2|A_1)*P(A_3 | A_1 A_2) ... P(A_n | A_1 A_2 ... A_{n-1})$
#
# = $P(A_1)\frac{P(A_1 A_2)}{P(A_1)} * \frac{P(A_1 A_2 A_3)}{P(A_1 A_2)} ... \frac{P(A_1 A_2 ... A_n)}{P(A_1 A_2 ... A_{n-1})} $
#
# = $P(A_1 A_2 ... A_n)$
#
#
# 例1:
#
#    设箱子内有a个白球,b个黑球,在其中不放回地连取3次,问前2次取到白球第3次取到黑球的概率。
#
#    解: 设事件$A_i$ 表示第i次抽到白球，
#
#    $P(A_1 A_2 \bar{A_3}) = P(A_1) * P(A_2 | A_1) * P(\bar{A_3} | A_1 A_2)$
#
#   = $\frac{a}{a+b}*\frac{a-1}{a+b-1}*\frac{b}{a+b+2}$
#
#
# ### ② 全概率公式
#
# 设 $B_1, B_2 ... B_n$ 是样本空间 Ω 的一个分割,即 $B_1, B_2, ... B_n$ 互不相容,且$\quad \bigcup_{i=1}^{n} B_i = $Ω 。如果P(B_i) > 0 (i = 1, 2, ..., n), 则对任一事件A，有
#
# $$P(A) = \sum_{i=1}^n P(B_i) P(A | B_i)$$
#
# 证明：P(A) = P(AΩ) =  $P(A\bigcap(B_1 \bigcup B_2 \bigcup ... \bigcup B_n))$
#
# $$=P(AB_1 \bigcup AB_2 \bigcup ... \bigcup AB_n)$$
# $$=P(AB_1) + P(AB_2) + ... + P(AB_n)$$
# $$=P(B_1)P(A|B_1)+ P(B_2)P(A|B_2) + ... + P(B_n)P(A|B_n)$$
#
# 如下图所示:
#
# ![match_derivatives](./img/b1_b2_b3_b4.png)
#
#
#
# $P(A) = P(AB_1) + P(AB_2) + P(AB_3) + P(AB_4) + P(B_i)P(A|B_i) + P(B_2)P(A|B_2) + P(B_3)P(A|B_3) + P(B_4)P(A|B_4)$
#
#
# 例1:
#
#  设甲箱中有a个白球，b个黑球，a > 0, b > 0, 乙箱中有c个白球，d个黑球。自甲箱中任取一球放入乙箱，然后再从乙箱中任取一个球。求最后由乙箱取出的是白球的概率。
#
#   解: 设事件A表示最后由乙箱取出的是白球,事件W表示从甲箱取出白球，
#
#   $P(A) = P(W)P(A|W) + P(\bar{W})P(A|\bar{W})$
#
#   $$= \frac{a}{a+b}*\frac{c+1}{c+d+1}+\frac{b}{a+b}*\frac{c}{c+d+1}$$
#
#   $$= \frac{ac + bc +1}{(a + b)(c + d +1)}$$
#
# 例2:
#
# 买彩票,设n张彩票中有1张奖券，人们排成一队购买彩票，求第k个人购到奖券的概率。
#
# 解1: 手部分析法 设置$A_k(n)$为事件 "n个人买彩票, 第k个人中奖", 则
#
# $P(A_k(n)) = P(A_1(n))P(A_k(n) | A_1(n)) + P(\bar{A_1(n)})P(A_k(n) | \bar{A_1(n)})$
#
# $$= 0+ \frac{n - 1}{n} P(A_{k-1})$$
#
# $$= \frac{n-1}{n} \frac{n-2}{n-1}P(A_{k-2}(n-2))$$
#
# $$= \frac{n-1}{n} \frac{n-2}{n-1}... \frac{n-(k-1)}{n-(k-2)}P(A_1(n-(k-1)))$$
#
# $$= \frac{n-1}{n}\frac{n-2}{n-1}...\frac{n-(k-1)}{n-(k-2)}\frac{1}{n-(k-1)} = \frac{1}{n}$$
#
# 解2:
#
#  设事件$A_i$表示事件"第i个人中奖",则
#
#  $P(A_k) = P(\bar{A_1}\bar{A_2}...\bar{A_{k-1}}A_k)$
#
#  $$= P(\bar{A_1})P(\bar{A_2} | \bar{A_1})...P(\bar{A_{k-1} | \bar{A_1} \bar{A_2} ... \bar{A_{k-2}}})P(A_k|\bar{A_1}\bar{A_2}...\bar{A_{k-1}})$$
#
#  $$= \frac{n-1}{n} \frac{n-2}{n-1}...\frac{n-k+1}{n-k+2}\frac{1}{n-k+1} = \frac{1}{n}$$
#
#
# ### ③ 贝叶斯(Bayes)公式
#
# 设$B_1, B_2, ... B_n$, 是样本空间Ω的一个分割,即$B_1, B_2，... B_n$ 互不相容，且$\quad \bigcup_{i=1}^{n} B_i = $Ω,如果 $P(A) > 0, P(B) > 0, (i = 1, 2 ... n)$,
#
# 则 $P(B_i | A) = \frac{P(B_i)P(A | B_i)}{\sum_{i=1}^n P(B_i)  P(A|B_i)}$
#
# 证明: $P(P(B_i | A)) = \frac{P(A | B_i)}{P(A)}$
#
# $$= \frac{P(B_i)P(A | B_i)}{P(B_i)P(A|B_1)+P(B)P(A|B_2)+...+P(B_n)(A|B_n)}$$
#
# 例1:
#
# 某考生回答一道有4个选择题，设会答该题的管理是P,并且会答时一定能答对，若不会时则在4个答案中任选择1个。求该考生回答正确时他确实会答的概率。
#
# 解: 设事件A表示"答对",事件B表示"会答",则
#
# $$P(B | A) = \frac{P(B)P(A|B)}{P(B)P(A|B) + P(B)P(A|\bar{B})}$$
#
# $$= \frac{p*1}{p*1 + (1 -p) * \frac{1}{4}}$$
#
# $$= \frac{4p}{1+3p}$$
#
# 例2:
#
#   一地区某疾病的发病率是0.0004.现有一种化验方法，真正得病得人，其化验结果99%呈阳性，对未患病者，化验结果99.9%呈阴性。求下列两事件得发生概率；
#
#   1. 检查结果呈阳性，是否真的患病？
#   2. 检查结果呈阴性，是否就可以放心地认为自己没有病？
#
# 解: 设事件A表示事件"化验呈阳性"，B表示"患病",则检查结果呈阳性，但实际上没有患病(虚惊一场的概率)
#
#  $$P(\bar{B} | A) = \frac{P(\bar{B}P(A | \bar{B}))}{P(B)P(A|B) + P(\bar{B}P(A|\bar{B}))} = \frac{0.9996 * 0.001}{0.0004 * 0.99 + 0.9996 * 0.001} = 0.716$$
#
# 检查结果呈阴性，但事实上是患了病的概率(患病但没有查出来的概率)
#
# $$P(B|\bar{A}) = \frac{P(B)P(\bar{A} | B)}{P(B)P(\bar{A} |B) + P(\bar{B})P(\bar{A}|B)} = \frac{0.0004 * 0.01}{0.0004 * 0.01 + 0.9996 * 0.999} = 4 * 10^{-6}$$
#
#
# ## 3， 事件的独立性
#
# 1. 事件独立是指互不影响:
#
#   $$P(A | B) = P(A)    P(B | A) = P(B)$$
#
# 2. 条件概率:
#
# $$P(A|B) = \frac{P(A | B)}{P(B)}   P(B | A) = \frac{P(AB)}{P(A)}$$
#
#
# 定义: 对于事件AB,如果P(AB) = P(A)P(B),则称事件A,B相互独立,简称A与B独立,否则称A与B不独立或相关。
#
#
# 例1:
#
# 若事件A和B事件独立,则A与$\bar{B}$独立,$\bar{A}$与B独立, $\bar{A}$与$\bar{B}$独立
#
# $$P(AB) = P(A) - P(AB) = p(A) - p(A)P(B)$$
#
# $$= P(A)(1-P(B)) = P(A)P(\bar{B})$$
#
# 利用  "事件$A$和$B$独立, 则$A$与$B$独立" 的结果：
#
# 得到的结论:
#
# 将A与B互换位置, 则得到$\bar{A}$与B独立
#
# 若 $ \bar{A}$ 与$B$独立,则 $\bar{A}$ 与 $\bar{B}$ 独立
#
# 例2:
#
# 3人独立破译密码,他们单独能破译的概率分别为$\frac{1}{5} \frac{1}{3} \frac{1}{4}$, 试求此密码能被破译出的概率。
#
# 解: 设事件B={该密码被破译},B={该密码为被破译}。
#
# 设事件$A_i$=(第i个人能破译密码) (i = 1, 2, 3),  则$\bar{B} = \bar{A_1} \bar{A_2} \bar{A_3}$
#
# $$P(B) = 1 - P(\bar{B}) = 1 - P(\bar{A_1} \bar{A_2} \bar{A_3}) = 1 - P(\bar{A_1})P(\bar{A_2})P(\bar{A_3})$$
#
# $$= 1 - (1- \frac{1}{5}) * (1 - \frac{1}{3}) * (1 - \frac{1}{4})) = \frac{3}{5}$$
#
#
# 3. 事件的独立于互不相容(互斥)
#
# ![](./img/A_B.png)
#
#
# 例 ： 网球比赛胜率的概率计算
#
# 网球的单打比赛规则: 网球单打比赛会进行若干局的争夺。
#
# 每一局比赛由同一位球员发球直至有其中一方赢取那局为止。
#
# 一局比赛中，赢第一球时得15分,赢第二球时记为得30分，赢第三球时记为40分。一方赢第四球时，另一方所得的分数如低于40分，则先赢四球者此局获胜。但如果双方同样取得40分，则进入到平方状态(Deuce)，进入到平分状态后，赢第一球者被称占先。如各赢一球则又进入平分状态(Deuce)。直至一方占先后，再赢得接下来的一球，即胜对手二球时,领先方赢得此局。
#
# 解:
#
#   现在假设两名球员，甲和乙，在一局比赛中，每个球甲的获胜率均为$p$，乙的获胜率为$q = 1- p$,并且在比赛过程中每个得分都是相互独立的事件。问甲，乙两人各自赢得这一局比赛的概率。
#
#   我们考虑更一般的情况。甲，乙两名球员进行每局m(网球是m=4，乒乓球m=11)分制的比赛，一方率先得到m分，同时领先对手至少2分时获胜。如果比赛出现 m-1 ：m -1，则进行至首次出现一方领先2分时，领先分获胜。
#
# 令$w(i, j)$表示甲已得i分,乙已得j分情况下甲获胜一局的概率，
#
# 根据比赛规则与概率假设有
#
# 1. 边界条件
#
#   $$\begin{cases} w(i, j), & \text {当 i >= m, i - j >= 2 时} \\ w(i, j), & \text{当 j>=m, j - i >= 2 时} \\ w(m-2, m-2) = w(m-1, m-1)= w(m, m)= ..., & \text{} \end{cases}$$
#
#
# 2. 递推关系
#
# 甲已得i分,乙已得j分后，继续比赛1分，全概率公式得到下面的
#
# $w(i, j)$ = P(第i + j + 1个球甲获胜) * P(甲赢得这一局的胜利  | 第 i + j + 1个球甲获胜) + P(第i + j + 1个球乙获胜) * P(甲赢得这一局的胜利 | 第 i  + j + 1球乙获胜)
#
# 即全概率公式:
#
# $w(i, j) = p * w(i + 1, j) + q * w(i, j + 1)$
#
#
# 根据上面的递推关系（2）与边界条件（1）即可计算得到任意w(i, j),  0 <= i, j <= m的值，
#
#
# 其中$w(0,0)$即为甲球员在一局比赛中的获胜概率。
#
# 网球比赛的单局胜率，即m=4情况下，计算$w(0,0)$由全概率公式展开
#
# $w(0,0) = p * w(1, 0) + q * w(0, 1)$
#
#
# $\begin{cases} w(1, 0) = p * w(2, 0) + q * w(1, 1) \\ w(0, 1) = p * w(1, 1) + q * w(0, 2) \end{cases}$
#
# 带入到$w(0,0)$公式中得到下面的公式
#
# $\Rightarrow$ $w(0, 0) = p * w(1, 0) + q * w(0, 1) = p^2 * w(2, 0) + 2pq * w(1, 1) + q^2 * w(0, 2)$
#
# 容易得到3个球的
#
# $w(0,0) = p^3 * w(3, 0) + 3p^2q*w(2, 1) + 3pq^2 * w(1,2) + q^3 * w(0,3)$
#
# 4个球
#
# $w(0,0) = p^4 * w(4, 0) + 4p^3q * w(3, 1) + 6p^2q^2 * w(2, 2) + 4pq^3 * w(1, 3) + q^4 * w(0, 4)$
#
# $w(0,0) = p^4 * w(4, 0) + 4p^3q * w(3, 1) + 6p^2q^2 * w(2, 2) + 4pq^3 * w(1, 3)$
#
#
# 6个球
#
# $w(0,0) = p^6 * w(6,0) + 6p^5q * w(5,1) + 15p^4q^2 * w(4,2) + 20p^3q^3 * w(3, 3)$
#
# $w(0, 0) = p^6 + 6p^5q +15p^4q^2 + 20p^3q^3 * w(3,3)$
#
# 全概率公式
#
# $w(3,3) = p^3w(5,3)+2pq*w(4,4)+q^2*w(3,5) = p^2 +2pq*w(4,4)$
#
#
# -----
# $w(3,3) = p^2 + 2pq*w(4,4)$
#
# $w(3,3) = w(4,4)$
#
# -----
#
# 上面两个推出 $w(3,3) = \frac{p^2}{1-2pq}$
#
# $w(0,0) = p^6 + 6p^5q + 15p^4q^2 + 20p^3q^3* \frac{p^2}{1-2pq}$
#
#
# 带入一些具体的数值
#
# 网球比赛的单局获胜率比较
#
# |每球获胜率|单局获胜率|
# |:--|:--|
# |0.50|0.5000|
# |0.55|0.6231|
# |0.60|0.7357|
# |0.65|0.8296|
# |0.70|0.9008|
# |0.75|0.9782|
